# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammadHosseinYaghubi/accounting_app/blob/main/accounting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup Environment
# !git clone https://github.com/MohammadHosseinYaghubi/accounting_app.git
# %cd accounting_app

# Install dependencies
# !pip install tkinter  # برای رابط گرافیکی

# @title Run Accounting App
import os
import subprocess
from IPython.display import display, HTML

# برای نمایش خروجی GUI در Colab
display(HTML("""
<h3>Accounting App Demo</h3>
<p>This will launch the Tkinter application</p>
"""))

# اجرای برنامه
# !python accounting_demo.py
# Out:
# Cloning into 'accounting_app'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 26 (delta 7), reused 22 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 59.71 KiB | 5.97 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# [Errno 2] No such file or directory: 'your-repo'
# /content
# ERROR: Could not find a version that satisfies the requirement tkinter (from versions: none)
# ERROR: No matching distribution found for tkinter
# <h3>Accounting App Demo</h3>
# <p>This will launch the Tkinter application</p>
# python3: can't open file '/content/accounting_demo.py': [Errno 2] No such file or directory
